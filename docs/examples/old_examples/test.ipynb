# %%
import compas
from compas.datastructures import Mesh
from compas_notebook.viewer import Viewer
from compas.colors import Color
path_b = r"C:\Users\adellend\Code2\compas_3dec\src\compas_3dec\data\block.obj"

mesh = Mesh.from_obj(compas.get(path_b))
viewer = Viewer()
viewer.scene.add(mesh, color=Color.green())
viewer.show()
# Out:
# VBox(children=(HBox(children=(Button(icon='folder-open', layout=Layout(height='32px', width='48px'), style=But…
