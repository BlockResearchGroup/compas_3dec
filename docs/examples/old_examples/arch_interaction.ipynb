# %%
# from compas.scene import Scene
from compas.datastructures import Mesh
from compas_3dec.blockelement3dec import BlockElement
from compas_3dec.model_3dec import Model_3dec
from compas_3dec.data.arch import Arch
import os

# from compas_viewer import Viewer
from compas.colors import Color
from compas_3dec.interactions_3dec import Interaction3dec
from compas_3dec.rigid_interaction import RigidInteraction

# =============================================================================
# Input
# =============================================================================
arch = Arch(rise=5, span=10, thickness=0.5, depth=0.5, n=20)
meshes = arch.blocks()
# =============================================================================
# Model
# =============================================================================
# model = Model_3dec(working_path = r"C:\Users\adellend\Code2\compas_3dec\docs\examples" )
model = Model_3dec(working_path = os.getcwd())
for m in meshes:
    model.add_element(BlockElement(m))
model.elementlist[0].is_support = True
model.elementlist[-1].is_support = True

model.add_interaction(model.elementlist[1], model.elementlist[2], RigidInteraction())
model.add_interaction(model.elementlist[2], model.elementlist[3], RigidInteraction())
model.add_interaction(model.elementlist[-2], model.elementlist[-3], RigidInteraction())
model.add_interaction(model.elementlist[-3], model.elementlist[-4], RigidInteraction())
model.add_interaction(model.elementlist[-5], model.elementlist[-6], RigidInteraction())

# =============================================================================
# create geometry.dat
# =============================================================================
model.to_3dec_geometry_interactions()

# =============================================================================
# input material
# =============================================================================
# to be moved to compas_model
model.threedec_config.add_material("concrete", 2200, 35, 5000000, 0.8)

# =============================================================================
# create analysis.dat files
# =============================================================================
# calculate joint stiffness from material and geometric input
# to be changed considering the Material class from compas_model
model.threedec_config.get_joint_stiffness_one_material("concrete", 1, 0.1)
gravity_dat = model.threedec_config.set_gravity_analysis("concrete")

# =============================================================================
# run 3dec solver
# =============================================================================
model.run([gravity_dat])

# =============================================================================
# read results
# =============================================================================
init_dict = model.from_3dec_blocks("init_state.txt")
mapping_dict = model.mapping(init_dict)
grav_dict = model.from_3dec_blocks("grav_state.txt")
model.update_blocks(grav_dict,mapping_dict)

output_3dec_per_vertex = model.from_3dec_contacts("contact_grav.txt")





from compas_notebook.viewer import Viewer
viewer = Viewer()
# viewer.scene.context = "Notebook"
viewer.scene.add(model)
# scene = Scene(context= "Notebook")
# for e in model.elementlist:
#     viewer.scene.add(e)

# for edge, interaction in model.graph.edges(True):
#     # print(edge, interaction)
#     if isinstance(interaction["interaction"], Interaction3dec):
#         viewer.scene.add(
#         interaction["interaction"],
#         show_normal_force_lines=True,
#         show_shear_force_lines=False,
#         show_points = True,
#         show_mesh_normal_stress = True,
#         show_mesh_shear_stress = False,
#         )

viewer.show()
# Out:
# Checking in the current directory: c:\Users\adellend\Code2\compas_3dec\docs\examples
# Deleted init_state.txt
# Deleted grav_state.txt
# Deleted contact_grav.txt
# PyThreeJS Model elements registered.
# PyThreeJS SceneObjects registered.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 75
#      73 viewer = Viewer()
#      74 # viewer.scene.context = "Notebook"
# ---> 75 viewer.scene.add(model)
#      76 # scene = Scene(context= "Notebook")
#      77 # for e in model.elementlist:
#      78 #     viewer.scene.add(e)
#    (...)
#      89 #         show_mesh_shear_stress = False,
#      90 #         )
#      92 viewer.show()
#
# File ~\Code2\compas\src\compas\scene\scene.py:141, in Scene.add(self, item, parent, **kwargs)
#     135             raise Exception(
#     136                 "Object context should be the same as scene context: {} != {}".format(
#     137                     kwargs["context"], self.context
#     138                 )
#     139             )
#     140         del kwargs["context"]  # otherwist the SceneObject receives "context" twice, which results in an error
# --> 141     sceneobject = SceneObject(item, context=self.context, **kwargs)  # type: ignore
#     142 self.tree.add(sceneobject, parent=parent)
#     143 return sceneobject
#
# File ~\Code2\compas_3dec\src\compas_3dec\notebook\scene\modelobject.py:11, in ThreeModelObject.__init__(self, *args, **kwargs)
#      10 def __init__(self, *args, **kwargs):
# ---> 11     super().__init__(*args, **kwargs)
#
# File ~\Code2\compas_3dec\src\compas_3dec\scene\modelobject.py:41, in ModelObject.__init__(self, model, show_tree, show_graph, show_elements, show_interactions, show_element_faces, **kwargs)
#      39 for edge, interaction in model.graph.edges(True):
#      40     if isinstance(interaction["interaction"], Interaction3dec):
# ---> 41         self.add(
#      42             interaction["interaction"],
#      43             show_normal_force_lines=True,
#      44             show_shear_force_lines=False,
#      45             show_points=True,
#      46             show_mesh_normal_stress=True,
#      47             show_mesh_shear_stress=False,
#      48             show_resultant_force=True,
#      49             show_resultant_point=True,
#      50
#      51         )
#
# File ~\Code2\compas\src\compas\scene\sceneobject.py:243, in SceneObject.add(self, item, **kwargs)
#     237             raise Exception(
#     238                 "Child context should be the same as parent context: {} != {}".format(
#     239                     kwargs["context"], self.context
#     240                 )
#     241             )
#     242         del kwargs["context"]  # otherwist the SceneObject receives "context" twice, which results in an error
# --> 243     sceneobject = SceneObject(item, context=self.context, **kwargs)  # type: ignore
#     245 super(SceneObject, self).add(sceneobject)
#     246 return sceneobject
#
# File ~\Code2\compas_3dec\src\compas_3dec\notebook\scene\interactionobject.py:17, in ThreeInteractionObject.__init__(self, *args, **kwargs)
#      16 def __init__(self, *args, **kwargs):
# ---> 17     super().__init__(*args, **kwargs)
#
# File ~\Code2\compas_3dec\src\compas_3dec\scene\interactionobject.py:63, in InteractionObject.__init__(self, interaction, **kwargs)
#      60 super(InteractionObject, self).__init__(item=interaction, **kwargs)
#      62 self._interaction = interaction
# ---> 63 self.interaction.compute_force_display()
#      64 self.vertexcolor = kwargs.get("vertexcolor")
#      65 self.edgecolor = kwargs.get("edgecolor", self.contrastcolor)
#
# File ~\Code2\compas_3dec\src\compas_3dec\interactions_3dec.py:33, in Interaction3dec.compute_force_display(self, scale_factor)
#      29 self.resultant_force = []
#      30 self.resultant_point = []
# ---> 33 resultant_point_application = Point(self.forces_per_contact["resultant_point"][0],self.forces_per_contact["resultant_point"][1],self.forces_per_contact["resultant_point"][2])
#      34 self.resultant_point.append(resultant_point_application)
#      36 self.resultant_force.append(Line.from_point_and_vector(resultant_point_application, Vector(*self.forces_per_contact["resultant_force"])*scale_factor))
#
# TypeError: 'NoneType' object is not subscriptable
